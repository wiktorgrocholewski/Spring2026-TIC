# %%
# This file combines the 3 datasets into one final cleaned dataset

# %%
import pandas as pd
import numpy as np
import os

# Load datasets
corn_data = pd.read_csv("/Users/wiktor/TIC/Spring2026-TIC/data/daily_corn_prices.csv")
weather_data = pd.read_csv("/Users/wiktor/TIC/Spring2026-TIC/data/combined_daily_weather_data.csv")
soybean_data = pd.read_csv("/Users/wiktor/TIC/Spring2026-TIC/data/daily_soybean_prices.csv")  


# Merge datasets on 'date'
merged_data = corn_data.merge(weather_data, on='date', how='inner')
merged_data = merged_data.merge(soybean_data, on='date', how='inner')
