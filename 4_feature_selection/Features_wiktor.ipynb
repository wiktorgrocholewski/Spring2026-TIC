# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import KFold
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier

# Load feature matrix
df = pd.read_csv("/Users/wiktor/TIC/Spring2026-TIC/data/features_wiktor.csv"
)

print(f"Shape: {df.shape}")
print(f"Date range: {df.index.min().date()} to {df.index.max().date()}")
print(f"Label distribution:")
print(df['bin'].value_counts().sort_index())
print(f"  -1 = Stop Loss | 0 = Time-out | 1 = Profit Take")

# Check for missing values
print(f"\nMissing values per column:")
missing = df.isnull().sum()
missing = missing[missing > 0].sort_values(ascending=False)
if len(missing) > 0:
    print(missing.head(20))
else:
    print("None ✓")
# Out:
# Shape: (1804, 137)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 18
#      14 df = pd.read_csv("/Users/wiktor/TIC/Spring2026-TIC/data/features_wiktor.csv"
#      15 )
#      17 print(f"Shape: {df.shape}")
# ---> 18 print(f"Date range: {df.index.min().date()} to {df.index.max().date()}")
#      19 print(f"Label distribution:")
#      20 print(df['bin'].value_counts().sort_index())
#
# AttributeError: 'int' object has no attribute 'date'

# %%
# Out:
# Collecting xgboost
#   Downloading xgboost-3.2.0-py3-none-macosx_10_15_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in /Users/wiktor/opt/anaconda3/envs/Bayes/lib/python3.11/site-packages (from xgboost) (2.3.1)
# Requirement already satisfied: scipy in /Users/wiktor/opt/anaconda3/envs/Bayes/lib/python3.11/site-packages (from xgboost) (1.16.3)
# Downloading xgboost-3.2.0-py3-none-macosx_10_15_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 10.0 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: xgboost
# Successfully installed xgboost-3.2.0
# Note: you may need to restart the kernel to use updated packages.
